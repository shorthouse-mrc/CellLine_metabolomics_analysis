# %%
import pandas as pd
import numpy as np

import sklearn.linear_model
import statsmodels.api as sm
from scipy import stats
from scipy.stats import zscore

from collections import Counter

# %%
cancer_genes = pd.read_csv("../../COSMIC/Census_allTue Nov 10 13_38_57 2020.csv")
cancer_genes = cancer_genes["Gene Symbol"].tolist()

# %%
celllines_mapped = pd.read_csv("../MCF7_removal/Celllines_mapping_manual_noMCF7.csv")
celllines_mutations = pd.read_csv("../../GEMICCL/Mutation.csv", sep = "\t")
# Out:
# C:\Users\ds728\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Get only cell lines with ID
celllines_mapped = celllines_mapped.drop_duplicates(subset = ["dsIdx"])
celllines_mapped = celllines_mapped.dropna(subset = ["ID"])
sample_data_tissue = celllines_mapped["DI"].tolist()

# %%
tissue_origin = pd.read_excel("../../Cellosaurus_data/Cellline_tissue_origin.xlsx", columns = ["Cancer", "Origin"])
tissue_origin_dict = tissue_origin.set_index("Cancer")["Origin"].to_dict()

# %%
tissue_type = []
for item in sample_data_tissue:
    if pd.isnull(item):
        tissue_type.append("Unknown") 
    elif item == "[]":
        tissue_type.append("Unknown")
    else:
        item = item.split(";")[2].split("'")[0].strip()
        tissue_type.append(item)
        
cell_origin = [tissue_origin_dict.get(item) for item in tissue_type]
celllines_mapped["Tissue"] = cell_origin

# %%
celllines_list = celllines_mapped["ID"].unique().tolist()

# %%
celllines_notinmutationset = set(celllines_list) - set(celllines_mutations['CellLineName_Cellosaurus'])
celllines_mapped_mutations = celllines_mapped[~celllines_mapped["ID"].isin(celllines_notinmutationset)]

# %%
tissue_labelled = pd.get_dummies(celllines_mapped_mutations, columns=["Tissue"])

# %%
metabolomics_data = pd.read_csv("../MCF7_removal/Metabolomics_data_noMCF7.csv")
metabolomics_data = metabolomics_data.set_index("ionIdx")

# %%
gene_array = []

count = 1
#iterate through genes
for gene in cancer_genes:
    print("Calculating for " + gene + " %s/%s" % (str(count), str(len(cancer_genes))))
    count+=1
    ## Figure out which cell lines have mutations in the gene
    gene_of_interest = celllines_mutations[celllines_mutations["HGNC"] == gene]
    gene_of_interest = gene_of_interest[gene_of_interest["MutationType"] != "Silent"]
    gene_of_interest_celllines = set(gene_of_interest["CellLineName_Cellosaurus"])
    
    ## Get the cell lines with mutations
    cellines_with_mutation = celllines_mapped_mutations[celllines_mapped_mutations["ID"].isin(gene_of_interest_celllines)]["dsIdx"].tolist()
    cellines_without_mutation = celllines_mapped_mutations[~celllines_mapped_mutations["ID"].isin(gene_of_interest_celllines)]["dsIdx"].tolist()
    cellines_with_mutation = [str(x) for x in cellines_with_mutation]
    cellines_without_mutation = [str(x) for x in cellines_without_mutation]
    
    ## Get the metabolomics data
    mutated_celllines = metabolomics_data[cellines_with_mutation].transpose()
    nonmutated_celllines = metabolomics_data[cellines_without_mutation].transpose()
    
    # If there are no mutations found then ignore this gene
    if mutated_celllines.empty:
        print("No mutations found for " + gene)
        continue
    
    ## Generate an array with the cell line metabolomics plus a tag for mutated for gene of interest
    mutated_celllines["Mutation"] = 1
    nonmutated_celllines["Mutation"] = 0
    
    celllines_labeled = pd.concat([mutated_celllines, nonmutated_celllines])
    celllines_labeled.index = celllines_labeled.index.map(str)
    
    ## Calculate tissue labels
    tissue_labels = []
    tissue_labels.append("dsIdx")
    for item in tissue_labelled.columns:
        if item.startswith("Tissue"):
            tissue_labels.append(item)
            
    tissue_labelled_tissue = tissue_labelled[tissue_labels].set_index("dsIdx")
    tissue_labelled_tissue.index = tissue_labelled_tissue.index.rename("") 
    tissue_labelled_tissue.index = tissue_labelled_tissue.index.map(str)
    
    ## Add tissue labels to regression model
    celllines_labeled = celllines_labeled.join(tissue_labelled_tissue)
    
    ## Set up for the logistic regression -> X is all metabolomics, Y is the mutated vs non mutated
    X = (celllines_labeled.drop(["Mutation"] + tissue_labels[1:], axis =1))
    Y = celllines_labeled["Mutation"]
    ## Zscore the metabolites across the cell line axis
    X= X.apply(zscore, axis =0)
    
    df_array = []
    Xsubset = X.copy()
    
    ## Generate a logistic regression model for every metabolite
    for item in range(1,X.shape[1]+1):
        Xsubset2 = Xsubset[item]
        X2 = sm.add_constant(Xsubset2)
        X2 = X2.join(tissue_labelled_tissue)
        est = sm.OLS(Y, X2)
        est2 = est.fit(disp=0)
        results_as_html = est2.summary().tables[1].as_html()
        summary = pd.read_html(results_as_html, header=0, index_col=0)[0]
        df_array.append(summary)
        
    ## Combine all of the resultant model data    
    array_concat = pd.concat(df_array)
    combined_array = array_concat[~array_concat.index.duplicated(keep='first')]
#    combined_array = combined_array.iloc[combined_array["t"].abs().argsort()]
    
    ## Get only the T values, and then append them to the master array for concatenation later
    tvalue_only = pd.DataFrame(combined_array["t"])
    t_name = "T_" + gene
    tvalue_only.columns = ([t_name])
    tvalue_only = tvalue_only.drop(tissue_labels[1:])
    
    gene_array.append(tvalue_only)
    
allgenes_scores = pd.concat(gene_array, axis =1)
allgenes_scores = allgenes_scores.drop("const", axis =0)
allgenes_scores.to_csv("OLS_tissue_controlled_regressionTstats_noMCF7.csv")
# Out:
# Calculating for A1CF 1/723
# Calculating for ABI1 2/723
# Calculating for ABL1 3/723
# Calculating for ABL2 4/723
# Calculating for ACKR3 5/723
# No mutations found for ACKR3
# Calculating for ACSL3 6/723
# Calculating for ACSL6 7/723
# Calculating for ACVR1 8/723
# Calculating for ACVR2A 9/723
# Calculating for AFDN 10/723
# No mutations found for AFDN
# Calculating for AFF1 11/723
# Calculating for AFF3 12/723
# Calculating for AFF4 13/723
# Calculating for AKAP9 14/723
# Calculating for AKT1 15/723
# Calculating for AKT2 16/723
# No mutations found for AKT2
# Calculating for AKT3 17/723
# Calculating for ALDH2 18/723
# Calculating for ALK 19/723
# Calculating for AMER1 20/723
# Calculating for ANK1 21/723
# Calculating for APC 22/723
# Calculating for APOBEC3B 23/723
# Calculating for AR 24/723
# Calculating for ARAF 25/723
# Calculating for ARHGAP26 26/723
# Calculating for ARHGAP5 27/723
# Calculating for ARHGEF10 28/723
# Calculating for ARHGEF10L 29/723
# Calculating for ARHGEF12 30/723
# Calculating for ARID1A 31/723
# Calculating for ARID1B 32/723
# Calculating for ARID2 33/723
# Calculating for ARNT 34/723
# Calculating for ASPSCR1 35/723
# Calculating for ASXL1 36/723
# Calculating for ASXL2 37/723
# Calculating for ATF1 38/723
# Calculating for ATIC 39/723
# Calculating for ATM 40/723
# Calculating for ATP1A1 41/723
# Calculating for ATP2B3 42/723
# Calculating for ATR 43/723
# Calculating for ATRX 44/723
# Calculating for AXIN1 45/723
# Calculating for AXIN2 46/723
# Calculating for B2M 47/723
# Calculating for BAP1 48/723
# Calculating for BARD1 49/723
# Calculating for BAX 50/723
# Calculating for BAZ1A 51/723
# Calculating for BCL10 52/723
# Calculating for BCL11A 53/723
# Calculating for BCL11B 54/723
# Calculating for BCL2 55/723
# No mutations found for BCL2
# Calculating for BCL2L12 56/723
# Calculating for BCL3 57/723
# Calculating for BCL6 58/723
# Calculating for BCL7A 59/723
# Calculating for BCL9 60/723
# Calculating for BCL9L 61/723
# Calculating for BCLAF1 62/723
# No mutations found for BCLAF1
# Calculating for BCOR 63/723
# Calculating for BCORL1 64/723
# Calculating for BCR 65/723
# Calculating for BIRC3 66/723
# Calculating for BIRC6 67/723
# Calculating for BLM 68/723
# Calculating for BMP5 69/723
# Calculating for BMPR1A 70/723
# Calculating for BRAF 71/723
# Calculating for BRCA1 72/723
# Calculating for BRCA2 73/723
# Calculating for BRD3 74/723
# Calculating for BRD4 75/723
# Calculating for BRIP1 76/723
# Calculating for BTG1 77/723
# Calculating for BTK 78/723
# Calculating for BUB1B 79/723
# Calculating for C15orf65 80/723
# No mutations found for C15orf65
# Calculating for CACNA1D 81/723
# Calculating for CALR 82/723
# Calculating for CAMTA1 83/723
# Calculating for CANT1 84/723
# No mutations found for CANT1
# Calculating for CARD11 85/723
# Calculating for CARS 86/723
# Calculating for CASP3 87/723
# Calculating for CASP8 88/723
# Calculating for CASP9 89/723
# Calculating for CBFA2T3 90/723
# Calculating for CBFB 91/723
# Calculating for CBL 92/723
# Calculating for CBLB 93/723
# Calculating for CBLC 94/723
# Calculating for CCDC6 95/723
# Calculating for CCNB1IP1 96/723
# Calculating for CCNC 97/723
# No mutations found for CCNC
# Calculating for CCND1 98/723
# Calculating for CCND2 99/723
# Calculating for CCND3 100/723
# Calculating for CCNE1 101/723
# Calculating for CCR4 102/723
# Calculating for CCR7 103/723
# Calculating for CD209 104/723
# Calculating for CD274 105/723
# No mutations found for CD274
# Calculating for CD28 106/723
# Calculating for CD74 107/723
# Calculating for CD79A 108/723
# Calculating for CD79B 109/723
# Calculating for CDC73 110/723
# Calculating for CDH1 111/723
# Calculating for CDH10 112/723
# Calculating for CDH11 113/723
# Calculating for CDH17 114/723
# Calculating for CDK12 115/723
# Calculating for CDK4 116/723
# No mutations found for CDK4
# Calculating for CDK6 117/723
# Calculating for CDKN1A 118/723
# Calculating for CDKN1B 119/723
# Calculating for CDKN2A 120/723
# Calculating for CDKN2C 121/723
# Calculating for CDX2 122/723
# Calculating for CEBPA 123/723
# No mutations found for CEBPA
# Calculating for CEP89 124/723
# Calculating for CHCHD7 125/723
# Calculating for CHD2 126/723
# Calculating for CHD4 127/723
# Calculating for CHEK2 128/723
# Calculating for CHIC2 129/723
# Calculating for CHST11 130/723
# No mutations found for CHST11
# Calculating for CIC 131/723
# Calculating for CIITA 132/723
# Calculating for CLIP1 133/723
# Calculating for CLP1 134/723
# Calculating for CLTC 135/723
# Calculating for CLTCL1 136/723
# Calculating for CNBD1 137/723
# Calculating for CNBP 138/723
# Calculating for CNOT3 139/723
# Calculating for CNTNAP2 140/723
# Calculating for CNTRL 141/723
# No mutations found for CNTRL
# Calculating for COL1A1 142/723
# Calculating for COL2A1 143/723
# Calculating for COL3A1 144/723
# Calculating for COX6C 145/723
# Calculating for CPEB3 146/723
# Calculating for CREB1 147/723
# Calculating for CREB3L1 148/723
# Calculating for CREB3L2 149/723
# Calculating for CREBBP 150/723
# Calculating for CRLF2 151/723
# No mutations found for CRLF2
# Calculating for CRNKL1 152/723
# Calculating for CRTC1 153/723
# Calculating for CRTC3 154/723
# Calculating for CSF1R 155/723
# Calculating for CSF3R 156/723
# Calculating for CSMD3 157/723
# Calculating for CTCF 158/723
# Calculating for CTNNA2 159/723
# Calculating for CTNNB1 160/723
# Calculating for CTNND1 161/723
# Calculating for CTNND2 162/723
# Calculating for CUL3 163/723
# Calculating for CUX1 164/723
# Calculating for CXCR4 165/723
# Calculating for CYLD 166/723
# Calculating for CYP2C8 167/723
# Calculating for CYSLTR2 168/723
# Calculating for DAXX 169/723
# Calculating for DCAF12L2 170/723
# Calculating for DCC 171/723
# Calculating for DCTN1 172/723
# Calculating for DDB2 173/723
# Calculating for DDIT3 174/723
# Calculating for DDR2 175/723
# Calculating for DDX10 176/723
# Calculating for DDX3X 177/723
# Calculating for DDX5 178/723
# Calculating for DDX6 179/723
# Calculating for DEK 180/723
# Calculating for DGCR8 181/723
# Calculating for DICER1 182/723
# Calculating for DNAJB1 183/723
# Calculating for DNM2 184/723
# Calculating for DNMT3A 185/723
# Calculating for DROSHA 186/723
# Calculating for DUX4L1 187/723
# No mutations found for DUX4L1
# Calculating for EBF1 188/723
# Calculating for ECT2L 189/723
# Calculating for EED 190/723
# Calculating for EGFR 191/723
# Calculating for EIF1AX 192/723
# Calculating for EIF3E 193/723
# Calculating for EIF4A2 194/723
# Calculating for ELF3 195/723
# Calculating for ELF4 196/723
# Calculating for ELK4 197/723
# Calculating for ELL 198/723
# Calculating for ELN 199/723
# Calculating for EML4 200/723
# Calculating for EP300 201/723
# Calculating for EPAS1 202/723
# Calculating for EPHA3 203/723
# Calculating for EPHA7 204/723
# Calculating for EPS15 205/723
# Calculating for ERBB2 206/723
# Calculating for ERBB3 207/723
# Calculating for ERBB4 208/723
# Calculating for ERC1 209/723
# Calculating for ERCC2 210/723
# Calculating for ERCC3 211/723
# Calculating for ERCC4 212/723
# Calculating for ERCC5 213/723
# Calculating for ERG 214/723
# Calculating for ESR1 215/723
# Calculating for ETNK1 216/723
# Calculating for ETV1 217/723
# Calculating for ETV4 218/723
# Calculating for ETV5 219/723
# Calculating for ETV6 220/723
# Calculating for EWSR1 221/723
# Calculating for EXT1 222/723
# Calculating for EXT2 223/723
# Calculating for EZH2 224/723
# Calculating for EZR 225/723
# Calculating for FAM131B 226/723
# Calculating for FAM135B 227/723
# Calculating for FAM47C 228/723
# Calculating for FANCA 229/723
# Calculating for FANCC 230/723
# Calculating for FANCD2 231/723
# Calculating for FANCE 232/723
# Calculating for FANCF 233/723
# Calculating for FANCG 234/723
# Calculating for FAS 235/723
# Calculating for FAT1 236/723
# Calculating for FAT3 237/723
# Calculating for FAT4 238/723
# Calculating for FBLN2 239/723
# Calculating for FBXO11 240/723
# Calculating for FBXW7 241/723
# Calculating for FCGR2B 242/723
# Calculating for FCRL4 243/723
# Calculating for FEN1 244/723
# Calculating for FES 245/723
# Calculating for FEV 246/723
# Calculating for FGFR1 247/723
# Calculating for FGFR1OP 248/723
# Calculating for FGFR2 249/723
# Calculating for FGFR3 250/723
# Calculating for FGFR4 251/723
# Calculating for FH 252/723
# Calculating for FHIT 253/723
# Calculating for FIP1L1 254/723
# Calculating for FKBP9 255/723
# Calculating for FLCN 256/723
# Calculating for FLI1 257/723
# Calculating for FLNA 258/723
# Calculating for FLT3 259/723
# Calculating for FLT4 260/723
# Calculating for FNBP1 261/723
# Calculating for FOXA1 262/723
# No mutations found for FOXA1
# Calculating for FOXL2 263/723
# Calculating for FOXO1 264/723
# Calculating for FOXO3 265/723
# Calculating for FOXO4 266/723
# Calculating for FOXP1 267/723
# Calculating for FOXR1 268/723
# Calculating for FSTL3 269/723
# No mutations found for FSTL3
# Calculating for FUBP1 270/723
# No mutations found for FUBP1
# Calculating for FUS 271/723
# Calculating for GAS7 272/723
# Calculating for GATA1 273/723
# Calculating for GATA2 274/723
# Calculating for GATA3 275/723
# Calculating for GLI1 276/723
# Calculating for GMPS 277/723
# Calculating for GNA11 278/723
# Calculating for GNAQ 279/723
# Calculating for GNAS 280/723
# Calculating for GOLGA5 281/723
# Calculating for GOPC 282/723
# Calculating for GPC3 283/723
# Calculating for GPC5 284/723
# Calculating for GPHN 285/723
# Calculating for GRIN2A 286/723
# Calculating for GRM3 287/723
# Calculating for H3F3A 288/723
# Calculating for H3F3B 289/723
# Calculating for HERPUD1 290/723
# Calculating for HEY1 291/723
# Calculating for HIF1A 292/723
# Calculating for HIP1 293/723
# Calculating for HIST1H3B 294/723
# Calculating for HIST1H4I 295/723
# Calculating for HLA-A 296/723
# Calculating for HLF 297/723
# Calculating for HMGA1 298/723
# Calculating for HMGA2 299/723
# Calculating for HMGN2P46 300/723
# No mutations found for HMGN2P46
# Calculating for HNF1A 301/723
# Calculating for HNRNPA2B1 302/723
# Calculating for HOOK3 303/723
# Calculating for HOXA11 304/723
# Calculating for HOXA13 305/723
# Calculating for HOXA9 306/723
# Calculating for HOXC11 307/723
# Calculating for HOXC13 308/723
# Calculating for HOXD11 309/723
# Calculating for HOXD13 310/723
# Calculating for HRAS 311/723
# Calculating for HSP90AA1 312/723
# Calculating for HSP90AB1 313/723
# Calculating for ID3 314/723
# No mutations found for ID3
# Calculating for IDH1 315/723
# Calculating for IDH2 316/723
# Calculating for IGF2BP2 317/723
# Calculating for IGH 318/723
# No mutations found for IGH
# Calculating for IGK 319/723
# No mutations found for IGK
# Calculating for IGL 320/723
# No mutations found for IGL
# Calculating for IKBKB 321/723
# Calculating for IKZF1 322/723
# Calculating for IL2 323/723
# Calculating for IL21R 324/723
# Calculating for IL6ST 325/723
# Calculating for IL7R 326/723
# Calculating for IRF4 327/723
# Calculating for IRS4 328/723
# Calculating for ISX 329/723
# Calculating for ITGAV 330/723
# Calculating for ITK 331/723
# Calculating for JAK1 332/723
# Calculating for JAK2 333/723
# Calculating for JAK3 334/723
# Calculating for JAZF1 335/723
# Calculating for JUN 336/723
# Calculating for KAT6A 337/723
# No mutations found for KAT6A
# Calculating for KAT6B 338/723
# Calculating for KAT7 339/723
# No mutations found for KAT7
# Calculating for KCNJ5 340/723
# Calculating for KDM5A 341/723
# Calculating for KDM5C 342/723
# Calculating for KDM6A 343/723
# Calculating for KDR 344/723
# Calculating for KDSR 345/723
# Calculating for KEAP1 346/723
# Calculating for KIAA1549 347/723
# Calculating for KIF5B 348/723
# Calculating for KIT 349/723
# Calculating for KLF4 350/723
# Calculating for KLF6 351/723
# Calculating for KLK2 352/723
# Calculating for KMT2A 353/723
# Calculating for KMT2C 354/723
# Calculating for KMT2D 355/723
# Calculating for KNL1 356/723
# No mutations found for KNL1
# Calculating for KNSTRN 357/723
# No mutations found for KNSTRN
# Calculating for KRAS 358/723
# Calculating for KTN1 359/723
# Calculating for LARP4B 360/723
# Calculating for LASP1 361/723
# Calculating for LATS1 362/723
# Calculating for LATS2 363/723
# Calculating for LCK 364/723
# Calculating for LCP1 365/723
# Calculating for LEF1 366/723
# Calculating for LEPROTL1 367/723
# No mutations found for LEPROTL1
# Calculating for LHFPL6 368/723
# No mutations found for LHFPL6
# Calculating for LIFR 369/723
# Calculating for LMNA 370/723
# Calculating for LMO1 371/723
# No mutations found for LMO1
# Calculating for LMO2 372/723
# Calculating for LPP 373/723
# Calculating for LRIG3 374/723
# Calculating for LRP1B 375/723
# Calculating for LSM14A 376/723
# Calculating for LYL1 377/723
# Calculating for LZTR1 378/723
# Calculating for MACC1 379/723
# Calculating for MAF 380/723
# Calculating for MAFB 381/723
# Calculating for MALAT1 382/723
# No mutations found for MALAT1
# Calculating for MALT1 383/723
# Calculating for MAML2 384/723
# Calculating for MAP2K1 385/723
# Calculating for MAP2K2 386/723
# Calculating for MAP2K4 387/723
# Calculating for MAP3K1 388/723
# Calculating for MAP3K13 389/723
# Calculating for MAPK1 390/723
# Calculating for MAX 391/723
# Calculating for MB21D2 392/723
# Calculating for MDM2 393/723
# Calculating for MDM4 394/723
# Calculating for MDS2 395/723
# No mutations found for MDS2
# Calculating for MECOM 396/723
# Calculating for MED12 397/723
# Calculating for MEN1 398/723
# Calculating for MET 399/723
# Calculating for MGMT 400/723
# Calculating for MITF 401/723
# Calculating for MLF1 402/723
# Calculating for MLH1 403/723
# Calculating for MLLT1 404/723
# Calculating for MLLT10 405/723
# Calculating for MLLT11 406/723
# Calculating for MLLT3 407/723
# Calculating for MLLT6 408/723
# Calculating for MN1 409/723
# Calculating for MNX1 410/723
# Calculating for MPL 411/723
# Calculating for MRTFA 412/723
# No mutations found for MRTFA
# Calculating for MSH2 413/723
# Calculating for MSH6 414/723
# Calculating for MSI2 415/723
# Calculating for MSN 416/723
# Calculating for MTCP1 417/723
# Calculating for MTOR 418/723
# Calculating for MUC1 419/723
# Calculating for MUC16 420/723
# Calculating for MUC4 421/723
# Calculating for MUTYH 422/723
# Calculating for MYB 423/723
# Calculating for MYC 424/723
# Calculating for MYCL 425/723
# No mutations found for MYCL
# Calculating for MYCN 426/723
# Calculating for MYD88 427/723
# Calculating for MYH11 428/723
# Calculating for MYH9 429/723
# Calculating for MYO5A 430/723
# Calculating for MYOD1 431/723
# Calculating for N4BP2 432/723
# Calculating for NAB2 433/723
# Calculating for NACA 434/723
# Calculating for NBEA 435/723
# Calculating for NBN 436/723
# Calculating for NCKIPSD 437/723
# Calculating for NCOA1 438/723
# Calculating for NCOA2 439/723
# Calculating for NCOA4 440/723
# Calculating for NCOR1 441/723
# Calculating for NCOR2 442/723
# Calculating for NDRG1 443/723
# Calculating for NF1 444/723
# Calculating for NF2 445/723
# Calculating for NFATC2 446/723
# Calculating for NFE2L2 447/723
# Calculating for NFIB 448/723
# Calculating for NFKB2 449/723
# Calculating for NFKBIE 450/723
# No mutations found for NFKBIE
# Calculating for NIN 451/723
# Calculating for NKX2-1 452/723
# Calculating for NONO 453/723
# Calculating for NOTCH1 454/723
# Calculating for NOTCH2 455/723
# Calculating for NPM1 456/723
# Calculating for NR4A3 457/723
# Calculating for NRAS 458/723
# Calculating for NRG1 459/723
# Calculating for NSD1 460/723
# Calculating for NSD2 461/723
# No mutations found for NSD2
# Calculating for NSD3 462/723
# No mutations found for NSD3
# Calculating for NT5C2 463/723
# Calculating for NTHL1 464/723
# No mutations found for NTHL1
# Calculating for NTRK1 465/723
# Calculating for NTRK3 466/723
# Calculating for NUMA1 467/723
# Calculating for NUP214 468/723
# Calculating for NUP98 469/723
# Calculating for NUTM1 470/723
# No mutations found for NUTM1
# Calculating for NUTM2B 471/723
# Calculating for NUTM2D 472/723
# No mutations found for NUTM2D
# Calculating for OLIG2 473/723
# No mutations found for OLIG2
# Calculating for OMD 474/723
# Calculating for P2RY8 475/723
# No mutations found for P2RY8
# Calculating for PABPC1 476/723
# Calculating for PAFAH1B2 477/723
# Calculating for PALB2 478/723
# Calculating for PATZ1 479/723
# Calculating for PAX3 480/723
# Calculating for PAX5 481/723
# Calculating for PAX7 482/723
# Calculating for PAX8 483/723
# Calculating for PBRM1 484/723
# Calculating for PBX1 485/723
# Calculating for PCBP1 486/723
# Calculating for PCM1 487/723
# Calculating for PDCD1LG2 488/723
# Calculating for PDE4DIP 489/723
# Calculating for PDGFB 490/723
# Calculating for PDGFRA 491/723
# Calculating for PDGFRB 492/723
# Calculating for PER1 493/723
# Calculating for PHF6 494/723
# No mutations found for PHF6
# Calculating for PHOX2B 495/723
# Calculating for PICALM 496/723
# Calculating for PIK3CA 497/723
# Calculating for PIK3CB 498/723
# Calculating for PIK3R1 499/723
# Calculating for PIM1 500/723
# Calculating for PLAG1 501/723
# Calculating for PLCG1 502/723
# Calculating for PML 503/723
# Calculating for PMS1 504/723
# Calculating for PMS2 505/723
# Calculating for POLD1 506/723
# Calculating for POLE 507/723
# Calculating for POLG 508/723
# Calculating for POLQ 509/723
# Calculating for POT1 510/723
# Calculating for POU2AF1 511/723
# Calculating for POU5F1 512/723
# Calculating for PPARG 513/723
# Calculating for PPFIBP1 514/723
# Calculating for PPM1D 515/723
# Calculating for PPP2R1A 516/723
# Calculating for PPP6C 517/723
# Calculating for PRCC 518/723
# Calculating for PRDM1 519/723
# Calculating for PRDM16 520/723
# Calculating for PRDM2 521/723
# Calculating for PREX2 522/723
# Calculating for PRF1 523/723
# Calculating for PRKACA 524/723
# Calculating for PRKAR1A 525/723
# Calculating for PRKCB 526/723
# Calculating for PRPF40B 527/723
# Calculating for PRRX1 528/723
# Calculating for PSIP1 529/723
# Calculating for PTCH1 530/723
# Calculating for PTEN 531/723
# Calculating for PTK6 532/723
# Calculating for PTPN11 533/723
# Calculating for PTPN13 534/723
# Calculating for PTPN6 535/723
# Calculating for PTPRB 536/723
# Calculating for PTPRC 537/723
# Calculating for PTPRD 538/723
# Calculating for PTPRK 539/723
# Calculating for PTPRT 540/723
# Calculating for PWWP2A 541/723
# Calculating for QKI 542/723
# Calculating for RABEP1 543/723
# Calculating for RAC1 544/723
# Calculating for RAD17 545/723
# No mutations found for RAD17
# Calculating for RAD21 546/723
# Calculating for RAD51B 547/723
# No mutations found for RAD51B
# Calculating for RAF1 548/723
# Calculating for RALGDS 549/723
# Calculating for RANBP2 550/723
# Calculating for RAP1GDS1 551/723
# Calculating for RARA 552/723
# Calculating for RB1 553/723
# Calculating for RBM10 554/723
# Calculating for RBM15 555/723
# Calculating for RECQL4 556/723
# Calculating for REL 557/723
# Calculating for RET 558/723
# Calculating for RFWD3 559/723
# Calculating for RGPD3 560/723
# Calculating for RGS7 561/723
# Calculating for RHOA 562/723
# Calculating for RHOH 563/723
# Calculating for RMI2 564/723
# No mutations found for RMI2
# Calculating for RNF213 565/723
# Calculating for RNF43 566/723
# Calculating for ROBO2 567/723
# Calculating for ROS1 568/723
# Calculating for RPL10 569/723
# Calculating for RPL22 570/723
# Calculating for RPL5 571/723
# Calculating for RPN1 572/723
# Calculating for RSPO2 573/723
# Calculating for RSPO3 574/723
# Calculating for RUNX1 575/723
# Calculating for RUNX1T1 576/723
# Calculating for S100A7 577/723
# Calculating for SALL4 578/723
# Calculating for SBDS 579/723
# Calculating for SDC4 580/723
# No mutations found for SDC4
# Calculating for SDHA 581/723
# Calculating for SDHAF2 582/723
# Calculating for SDHB 583/723
# Calculating for SDHC 584/723
# Calculating for SDHD 585/723
# No mutations found for SDHD
# Calculating for SEPT5 586/723
# Calculating for SEPT6 587/723
# Calculating for SEPT9 588/723
# Calculating for SET 589/723
# Calculating for SETBP1 590/723
# Calculating for SETD1B 591/723
# Calculating for SETD2 592/723
# Calculating for SETDB1 593/723
# Calculating for SF3B1 594/723
# Calculating for SFPQ 595/723
# Calculating for SFRP4 596/723
# Calculating for SGK1 597/723
# Calculating for SH2B3 598/723
# Calculating for SH3GL1 599/723
# Calculating for SHTN1 600/723
# No mutations found for SHTN1
# Calculating for SIRPA 601/723
# Calculating for SIX1 602/723
# No mutations found for SIX1
# Calculating for SIX2 603/723
# Calculating for SKI 604/723
# Calculating for SLC34A2 605/723
# Calculating for SLC45A3 606/723
# Calculating for SMAD2 607/723
# Calculating for SMAD3 608/723
# Calculating for SMAD4 609/723
# Calculating for SMARCA4 610/723
# Calculating for SMARCB1 611/723
# Calculating for SMARCD1 612/723
# Calculating for SMARCE1 613/723
# No mutations found for SMARCE1
# Calculating for SMC1A 614/723
# Calculating for SMO 615/723
# Calculating for SND1 616/723
# Calculating for SNX29 617/723
# Calculating for SOCS1 618/723
# Calculating for SOX2 619/723
# Calculating for SOX21 620/723
# Calculating for SPECC1 621/723
# No mutations found for SPECC1
# Calculating for SPEN 622/723
# Calculating for SPOP 623/723
# Calculating for SRC 624/723
# Calculating for SRGAP3 625/723
# Calculating for SRSF2 626/723
# No mutations found for SRSF2
# Calculating for SRSF3 627/723
# Calculating for SS18 628/723
# Calculating for SS18L1 629/723
# Calculating for SSX1 630/723
# Calculating for SSX2 631/723
# No mutations found for SSX2
# Calculating for SSX4 632/723
# No mutations found for SSX4
# Calculating for STAG1 633/723
# Calculating for STAG2 634/723
# Calculating for STAT3 635/723
# Calculating for STAT5B 636/723
# Calculating for STAT6 637/723
# Calculating for STIL 638/723
# Calculating for STK11 639/723
# Calculating for STRN 640/723
# Calculating for SUFU 641/723
# Calculating for SUZ12 642/723
# Calculating for SYK 643/723
# Calculating for TAF15 644/723
# Calculating for TAL1 645/723
# Calculating for TAL2 646/723
# Calculating for TBL1XR1 647/723
# Calculating for TBX3 648/723
# Calculating for TCEA1 649/723
# Calculating for TCF12 650/723
# Calculating for TCF3 651/723
# Calculating for TCF7L2 652/723
# Calculating for TCL1A 653/723
# Calculating for TEC 654/723
# Calculating for TENT5C 655/723
# No mutations found for TENT5C
# Calculating for TERT 656/723
# Calculating for TET1 657/723
# Calculating for TET2 658/723
# Calculating for TFE3 659/723
# Calculating for TFEB 660/723
# Calculating for TFG 661/723
# No mutations found for TFG
# Calculating for TFPT 662/723
# Calculating for TFRC 663/723
# Calculating for TGFBR2 664/723
# Calculating for THRAP3 665/723
# Calculating for TLX1 666/723
# Calculating for TLX3 667/723
# No mutations found for TLX3
# Calculating for TMEM127 668/723
# No mutations found for TMEM127
# Calculating for TMPRSS2 669/723
# Calculating for TNC 670/723
# Calculating for TNFAIP3 671/723
# Calculating for TNFRSF14 672/723
# No mutations found for TNFRSF14
# Calculating for TNFRSF17 673/723
# Calculating for TOP1 674/723
# Calculating for TP53 675/723
# Calculating for TP63 676/723
# Calculating for TPM3 677/723
# Calculating for TPM4 678/723
# Calculating for TPR 679/723
# Calculating for TRA 680/723
# No mutations found for TRA
# Calculating for TRAF7 681/723
# Calculating for TRB 682/723
# No mutations found for TRB
# Calculating for TRD 683/723
# No mutations found for TRD
# Calculating for TRIM24 684/723
# Calculating for TRIM27 685/723
# Calculating for TRIM33 686/723
# Calculating for TRIP11 687/723
# Calculating for TRRAP 688/723
# Calculating for TSC1 689/723
# Calculating for TSC2 690/723
# Calculating for TSHR 691/723
# Calculating for U2AF1 692/723
# Calculating for UBR5 693/723
# Calculating for USP44 694/723
# Calculating for USP6 695/723
# Calculating for USP8 696/723
# Calculating for VAV1 697/723
# Calculating for VHL 698/723
# Calculating for VTI1A 699/723
# Calculating for WAS 700/723
# Calculating for WDCP 701/723
# No mutations found for WDCP
# Calculating for WIF1 702/723
# Calculating for WNK2 703/723
# Calculating for WRN 704/723
# Calculating for WT1 705/723
# Calculating for WWTR1 706/723
# No mutations found for WWTR1
# Calculating for XPA 707/723
# Calculating for XPC 708/723
# Calculating for XPO1 709/723
# Calculating for YWHAE 710/723
# Calculating for ZBTB16 711/723
# Calculating for ZCCHC8 712/723
# Calculating for ZEB1 713/723
# Calculating for ZFHX3 714/723
# Calculating for ZMYM2 715/723
# Calculating for ZMYM3 716/723
# Calculating for ZNF331 717/723
# Calculating for ZNF384 718/723
# Calculating for ZNF429 719/723
# Calculating for ZNF479 720/723
# Calculating for ZNF521 721/723
# Calculating for ZNRF3 722/723
# Calculating for ZRSR2 723/723

# %%
count = 1
#iterate through genes
for gene in ["STK11", "KEAP1"]:
    print("Calculating for " + gene + " %s/%s" % (str(count), str(len(cancer_genes))))
    count+=1
    ## Figure out which cell lines have mutations in the gene
    gene_of_interest = celllines_mutations[celllines_mutations["HGNC"] == gene]
    gene_of_interest = gene_of_interest[gene_of_interest["MutationType"] != "Silent"]
    gene_of_interest_celllines = set(gene_of_interest["CellLineName_Cellosaurus"])
    
    ## Get the cell lines with mutations
    cellines_with_mutation = celllines_mapped_mutations[celllines_mapped_mutations["ID"].isin(gene_of_interest_celllines)]["dsIdx"].tolist()
    cellines_without_mutation = celllines_mapped_mutations[~celllines_mapped_mutations["ID"].isin(gene_of_interest_celllines)]["dsIdx"].tolist()
    cellines_with_mutation = [str(x) for x in cellines_with_mutation]
    cellines_without_mutation = [str(x) for x in cellines_without_mutation]
    
    ## Get the metabolomics data
    mutated_celllines = metabolomics_data[cellines_with_mutation].transpose()
    nonmutated_celllines = metabolomics_data[cellines_without_mutation].transpose()
    
    # If there are no mutations found then ignore this gene
    if mutated_celllines.empty:
        print("No mutations found for " + gene)
        continue
    
    ## Generate an array with the cell line metabolomics plus a tag for mutated for gene of interest
    mutated_celllines["Mutation"] = 1
    nonmutated_celllines["Mutation"] = 0
    
    celllines_labeled = pd.concat([mutated_celllines, nonmutated_celllines])
    celllines_labeled.index = celllines_labeled.index.map(str)
    
    ## Calculate tissue labels
    tissue_labels = []
    tissue_labels.append("dsIdx")
    for item in tissue_labelled.columns:
        if item.startswith("Tissue"):
            tissue_labels.append(item)
            
    tissue_labelled_tissue = tissue_labelled[tissue_labels].set_index("dsIdx")
    tissue_labelled_tissue.index = tissue_labelled_tissue.index.rename("") 
    tissue_labelled_tissue.index = tissue_labelled_tissue.index.map(str)
    
    ## Add tissue labels to regression model
    celllines_labeled = celllines_labeled.join(tissue_labelled_tissue)
    
    ## Set up for the logistic regression -> X is all metabolomics, Y is the mutated vs non mutated
    X = (celllines_labeled.drop(["Mutation"] + tissue_labels[1:], axis =1))
    Y = celllines_labeled["Mutation"]
    ## Zscore the metabolites across the cell line axis
    X= X.apply(zscore, axis =0)
    
    df_array = []
    Xsubset = X.copy()
    
    ## Generate a logistic regression model for every metabolite
    for item in range(1,X.shape[1]+1):
        Xsubset2 = Xsubset[item]
        X2 = sm.add_constant(Xsubset2)
        X2 = X2.join(tissue_labelled_tissue)
        est = sm.OLS(Y, X2)
        est2 = est.fit(disp=0)
        results_as_html = est2.summary().tables[1].as_html()
        summary = pd.read_html(results_as_html, header=0, index_col=0)[0]
        df_array.append(summary)
        
    ## Combine all of the resultant model data    
    array_concat = pd.concat(df_array)
    combined_array = array_concat[~array_concat.index.duplicated(keep='first')]
#    combined_array = combined_array.iloc[combined_array["t"].abs().argsort()]
    
    ## Get only the T values, and then append them to the master array for concatenation later
    tvalue_only = pd.DataFrame(combined_array["t"])
    t_name = "T_" + gene
    tvalue_only.columns = ([t_name])
    tvalue_only = tvalue_only.drop(tissue_labels[1:])
    
    gene_array.append(tvalue_only)
# Out:
# Calculating for STK11 1/723
# Calculating for KEAP1 2/723

# %%
allgenes_scores = pd.concat(gene_array, axis =1)
allgenes_scores = allgenes_scores.drop("const", axis =0)

# %%
allgenes_scores
# Out:
#       T_A1CF  T_ABI1  T_ABL1  T_ABL2  T_ACSL3  T_ACSL6  T_ACVR1  T_ACVR2A  \
# 1      0.512  -1.411   0.820   0.965    1.062    0.819    1.636     0.406
# 2     -0.717   0.131  -0.478  -0.526   -1.938   -1.302    0.695     0.664
# 3      4.089  -1.856   2.502   2.380    0.433    0.437    1.715     0.913
# 4      2.491  -1.549   1.566   0.412    1.760   -0.144    0.205     0.515
# 5      1.690  -1.875  -1.367  -0.445    0.498   -3.144    3.060    -1.079
# ...      ...     ...     ...     ...      ...      ...      ...       ...
# 1095  -1.478  -0.983   2.628  -0.130    2.124    3.727   -1.970    -0.691
# 1096   3.084  -3.491  -0.026   0.319   -1.155    2.897   -3.322    -3.216
# 1097  -1.422  -1.013  -1.836   8.034   -2.382   -3.233    2.700     0.218
# 1098   0.493  -0.783   1.186   1.395    2.422    2.337   -3.228    -2.723
# 1099   1.210  -0.337   0.947   2.190    2.520    2.952   -3.445    -2.276
#
#       T_AFF1  T_AFF3  ...  T_ZMYM3  T_ZNF331  T_ZNF384  T_ZNF429  T_ZNF479  \
# 1      2.722  -0.033  ...    0.709     0.146    -0.380    -0.068     2.859
# 2     -2.435   1.229  ...   -0.598    -1.078     0.378    -0.007     0.488
# 3      1.878   0.053  ...    1.354    -1.655     0.865     0.899     1.003
# 4      3.425   0.119  ...    0.903    -0.927     0.194     0.948     1.234
# 5      2.092  -0.496  ...    0.426    -0.249    -0.382     0.765     0.269
# ...      ...     ...  ...      ...       ...       ...       ...       ...
# 1095  -2.864  -1.769  ...   -1.567     1.667     0.374     4.238     1.901
# 1096  -2.406  -2.742  ...   -1.524     4.066    -0.121    -0.538    -1.456
# 1097   1.093  -0.351  ...   -2.770     7.673    -2.782    -0.686     1.912
# 1098  -1.300  -0.236  ...   -2.038     2.777     1.432     7.701    -0.390
# 1099  -0.134  -3.474  ...   -1.725     2.349     1.437     6.068     1.613
#
#       T_ZNF521  T_ZNRF3  T_ZRSR2  T_STK11  T_KEAP1
# 1       -1.630    1.854    0.363   -0.696   -0.119
# 2        0.858   -0.352   -0.813    0.320   -0.878
# 3        3.796    3.286    2.629   -0.280    2.450
# 4        0.376    1.619    1.253   -0.132    0.753
# 5       -1.725    0.790   -0.955    0.464    1.899
# ...        ...      ...      ...      ...      ...
# 1095    -2.139   -0.182   -0.500    5.101   -1.182
# 1096    -2.254   -0.281    0.011   -1.999   -1.700
# 1097    -1.992   -1.927   -1.477    6.480    7.699
# 1098     3.943    2.689   -1.609    1.319    0.862
# 1099     0.993    0.095   -2.178    2.717    2.026
#
# [1099 rows x 660 columns]

# %%
allgenes_scores.to_csv("OLS_tissue_controlled_regressionTstats_noMCF7.csv")
